# %% [markdown]
# # Punto 1:
#
# - `[15 pts]` Hacer Web Scraping de 10 animales en Wikipedia (en búcle)
# - `[10 pts]` Obtener el **encabezado** de cada animal
# - `[15 pts]` Obtener todos los **textos** que están en las etiquetas de negrilla.

# %%
import bs4 as bs 
import urllib.request

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("<html><p>This is <b>invalid HTML</p></html>", "lxml")
print(soup)
# Out:
# <html><body><p>This is <b>invalid HTML</b></p></body></html>

# %%
# Definición de lista de animales
a = 'Felis_silvestris_catus'
b = 'Elephantidae'
c = 'Canis_lupus'
d = 'Selachimorpha'
e = 'Spheniscidae'
f = 'Mammuthus'
g = 'Psittacoidea'
h = 'Caelifera'
i = 'Marmota'
j = 'Mono'

letras = [a, b, c, d, e, f, g, h, i, j] #Creación de conjunto de animales


print ('Títulos')
print ('---------')

for x in letras:

    direccion = 'https://es.wikipedia.org/wiki/' + x    #Creación de la URL
    
    soup = BeautifulSoup(urllib.request.urlopen(direccion))
           
    print (soup.h1.string)           #Imprimir los títulos
# Out:
# Títulos
# ---------
# Felis silvestris catus
# Elephantidae
# Canis lupus
# Selachimorpha
# Spheniscidae
# Mammuthus
# Psittacoidea
# Caelifera
# Marmota
# Mono

# %%
# Extrayendo el texto en negrita del primer párrafo de cada página


print ('Extracción de texto en negrita')
print ('---------')


for x in letras:

    direccion = 'https://es.wikipedia.org/wiki/' + x
    
    soup = BeautifulSoup(urllib.request.urlopen(direccion))
           
    #print (soup.h1.string)
    
    title = soup.select('p')[0].text.strip()
    
    for x in range(11):
        
        p = ((soup.find_all('b')[x + 1]).getText())
        
        print (p)
# Out:
# Extracción de texto en negrita
# ---------
# gato doméstico
# Felis silvestris catus
# gato
# minino
# michino
# michi
# micho
# mizo
# miz
# morroño
# morrongo
# elefantes
# elefántidos
# Elephantidae
# Elefantes africanos
# Elefantes asiáticos
# Emite sonidos
# infrasónicos
# recoge comida
# tiene el mejor olfato del mundo, la levantan en el aire a fin de percibir olores lejanos
# abrir camino, marcar árboles
# escarbar y para atacar y defenderse
# Distribución del lobo
# lobo
# Canis lupus
# Agresividad:
# Caza:
# Defensa:
# Dominio:
# Enfado:
# Felicidad:
# Miedo:
# Relajación:
# selaquimorfos
# selacimorfos
# Selachimorpha
# tiburones
# escualos
# jaquetones
# a
# b
# c
# d
# e
# Spheniscidae
# pingüinos
# Spheniscidae
# Sphenisciformes
# pájaros niño
# pájaros bobos
# pingüino
# Familia Spheniscidae
# a
# b
# c
# Mammuthus
# mamuts
# mamuts
# a
# b
# 429
# a
# b
# c
# a
# b
# Psittacoidea
# psitacoideos
# loros típicos
# a
# b
# 16-17
# 59
# 38
# 59
# 25
# 36
# caelíferos
# ...

# %%
# Punto 2 reemplazar todas las tíldes del punto anterior por un asterisco


print ('Reemplazo de vocales con tílde por *')
print ('---------')


import re
import unicodedata
from unicodedata import normalize


specialChars = 'áéíóú' #caracteres especiales a reemplazar


for x in letras:

    direccion = 'https://es.wikipedia.org/wiki/' + x
    
    soup = BeautifulSoup(urllib.request.urlopen(direccion))
           
    #print (soup.h1.string)
    
    title = soup.select('p')[0].text.strip()

    
    for x in range(11):
        
        p = ((soup.find_all('b')[x + 1]).getText())
        

    
        for specialChar in specialChars:
    
            p = p.replace(specialChar, '*')
    
        print(p)
        
        
    print ('---SALTO----')
# Out:
# Reemplazo de vocales con tílde por *
# ---------
# gato dom*stico
# Felis silvestris catus
# gato
# minino
# michino
# michi
# micho
# mizo
# miz
# morroño
# morrongo
# ---SALTO----
# elefantes
# elef*ntidos
# Elephantidae
# Elefantes africanos
# Elefantes asi*ticos
# Emite sonidos
# infras*nicos
# recoge comida
# tiene el mejor olfato del mundo, la levantan en el aire a fin de percibir olores lejanos
# abrir camino, marcar *rboles
# escarbar y para atacar y defenderse
# ---SALTO----
# Distribuci*n del lobo
# lobo
# Canis lupus
# Agresividad:
# Caza:
# Defensa:
# Dominio:
# Enfado:
# Felicidad:
# Miedo:
# Relajaci*n:
# ---SALTO----
# selaquimorfos
# selacimorfos
# Selachimorpha
# tiburones
# escualos
# jaquetones
# a
# b
# c
# d
# e
# ---SALTO----
# Spheniscidae
# pingüinos
# Spheniscidae
# Sphenisciformes
# p*jaros niño
# p*jaros bobos
# pingüino
# Familia Spheniscidae
# a
# b
# c
# ---SALTO----
# Mammuthus
# mamuts
# mamuts
# a
# b
# 429
# a
# b
# c
# a
# b
# ---SALTO----
# ...
